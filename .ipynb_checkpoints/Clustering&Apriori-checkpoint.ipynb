# %%
import sys
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="dark",color_codes=True)
import sklearn
from sklearn.cluster import KMeans

# %%
# Before clustering, let's find out the number of clusters that we need to apply

# %%
# Finding optimum number of clusters using The Elbow Method

from sklearn.cluster import KMeans
clust = dataa.iloc[:, 35:37].values
wcss = []

for i in range(1,5):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(clust)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,5),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
#Clustering - 
dataa = pd.read_csv("final.csv")
dataa = pd.DataFrame(dataa)

#print(dataa.head())

Data = pd.DataFrame(dataa,columns = ['Rent'])

import sklearn
from sklearn.cluster import KMeans

#print(Data)

# 3 clusters
kmeans = KMeans(n_clusters=3).fit(Data)
centroids = kmeans.cluster_centers_
print(centroids)
centroids = pd.DataFrame(centroids)
X= Data['Rent']


cluster_map = pd.DataFrame()
cluster_map['data_index'] = Data.index.values
cluster_map['cluster'] = kmeans.labels_

print(cluster_map[cluster_map.cluster == 0])
print(cluster_map[cluster_map.cluster == 1])
print(cluster_map[cluster_map.cluster == 2])

#plt.scatter(Data.index, X, c= kmeans.labels_.astype(float), s=50, alpha=0.5)
#plt.scatter(centroids.index,centroids, c='red', s=50)

plt.scatter(Data.index, X, c= kmeans.labels_.astype(float), s=50, alpha = 0.8)
plt.scatter(centroids.index,centroids, c='blue', s=50)

# %%
#Creating Dummy Variables for categorical features

l = ["EnrolmentTerm","BuildingType","RoomType","Furnished","SharedorPrivate","HouseAge","LocationWard"]
one_hot = pd.get_dummies(dataa[l])
dataa = dataa.drop(l,axis = 1)
dataa = one_hot.join(dataa)
print(dataa.head())
print(dataa.columns)

# %%
dataa.head()

# %%
new_data = dataa.iloc[:, 0:32]
new_data.head()

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori

# %%
fme = apriori(new_data, min_support=0.1, use_colnames=True)
fme

# %%
from mlxtend.frequent_patterns import association_rules

association_rules(fme, metric="confidence", min_threshold=0.7)

#http://rasbt.github.io/mlxtend/user_guide/frequent_patterns/association_rules/
# Out:
#                                              antecedents  \
# 0                                   (EnrolmentTerm_Fall)
# 1                                   (EnrolmentTerm_Fall)
# 2                                   (EnrolmentTerm_Fall)
# 3                                   (EnrolmentTerm_Fall)
# 4                                   (EnrolmentTerm_Fall)
# 5                                   (EnrolmentTerm_Fall)
# 6                                   (EnrolmentTerm_Fall)
# 7                                 (EnrolmentTerm_Spring)
# 8                                 (EnrolmentTerm_Spring)
# 9                                 (EnrolmentTerm_Spring)
# 10                                (EnrolmentTerm_Spring)
# 11                                (EnrolmentTerm_Spring)
# 12                                (EnrolmentTerm_Spring)
# 13                                (EnrolmentTerm_Spring)
# 14                                (EnrolmentTerm_Winter)
# 15                                (EnrolmentTerm_Winter)
# 16                                (EnrolmentTerm_Winter)
# 17                                (EnrolmentTerm_Winter)
# 18                                (EnrolmentTerm_Winter)
# 19                               (RoomType_Regular Room)
# 20                              (BuildingType_Apartment)
# 21                                       (Furnished_Yes)
# 22                              (BuildingType_Apartment)
# 23                              (SharedorPrivate_Shared)
# 24                              (BuildingType_Apartment)
# 25                                        (HouseAge_New)
# 26                      (LocationWard_4- Northeast ward)
# 27               (LocationWard_6- Central-Columbia ward)
# 28                                           (Internet )
# 29                              (BuildingType_Apartment)
# ...                                                  ...
# 27527  (Internet , BuildingType_Apartment, RoomType_R...
# 27528  (Internet , SharedorPrivate_Shared, Hydro, Roo...
# 27529  (Internet , SharedorPrivate_Shared, Hydro, Roo...
# 27530  (Internet , SharedorPrivate_Shared, Hydro, Roo...
# 27531  (Internet , SharedorPrivate_Shared, RoomType_R...
# 27532  (Internet , SharedorPrivate_Shared, RoomType_R...
# 27533  (Internet , SharedorPrivate_Shared, RoomType_R...
# 27534  (Internet , Hydro, RoomType_Regular Room, AirC...
# 27535  (BuildingType_Apartment, SharedorPrivate_Share...
# 27536  (BuildingType_Apartment, SharedorPrivate_Share...
# 27537  (BuildingType_Apartment, SharedorPrivate_Share...
# 27538  (BuildingType_Apartment, SharedorPrivate_Share...
# 27539  (BuildingType_Apartment, SharedorPrivate_Share...
# 27540  (BuildingType_Apartment, SharedorPrivate_Share...
# 27541  (BuildingType_Apartment, Hydro, RoomType_Regul...
# 27542  (SharedorPrivate_Shared, Hydro, RoomType_Regul...
# 27543  (SharedorPrivate_Shared, Hydro, RoomType_Regul...
# 27544  (SharedorPrivate_Shared, Hydro, RoomType_Regul...
# 27545  (SharedorPrivate_Shared, RoomType_Regular Room...
# 27546  (Internet , BuildingType_Apartment, SharedorPr...
# 27547  (Internet , SharedorPrivate_Shared, Hydro, Roo...
# 27548  (Internet , SharedorPrivate_Shared, RoomType_R...
# 27549  (Internet , SharedorPrivate_Shared, RoomType_R...
# 27550  (Internet , SharedorPrivate_Shared, RoomType_R...
# 27551  (BuildingType_Apartment, SharedorPrivate_Share...
# 27552  (BuildingType_Apartment, SharedorPrivate_Share...
# 27553  (BuildingType_Apartment, SharedorPrivate_Share...
# 27554  (SharedorPrivate_Shared, Hydro, RoomType_Regul...
# 27555  (SharedorPrivate_Shared, RoomType_Regular Room...
# 27556  (SharedorPrivate_Shared, Internet , HouseAge_N...
#
#                                              consequents  antecedent support  \
# 0                                (RoomType_Regular Room)            0.512438
# 1                                        (Furnished_Yes)            0.512438
# 2                               (SharedorPrivate_Shared)            0.512438
# 3                                            (Internet )            0.512438
# 4                                                (Hydro)            0.512438
# 5                                      (AirConditioning)            0.512438
# 6                                              (Laundry)            0.512438
# 7                               (BuildingType_Apartment)            0.283582
# 8                                        (Furnished_Yes)            0.283582
# 9                               (SharedorPrivate_Shared)            0.283582
# 10                                           (Internet )            0.283582
# 11                                               (Hydro)            0.283582
# 12                                     (AirConditioning)            0.283582
# 13                                             (Laundry)            0.283582
# 14                                       (Furnished_Yes)            0.203980
# 15                                           (Internet )            0.203980
# 16                                               (Hydro)            0.203980
# 17                                     (AirConditioning)            0.203980
# 18                                             (Laundry)            0.203980
# 19                              (BuildingType_Apartment)            0.671642
# 20                               (RoomType_Regular Room)            0.696517
# 21                              (BuildingType_Apartment)            0.815920
# 22                                       (Furnished_Yes)            0.696517
# 23                              (BuildingType_Apartment)            0.726368
# 24                              (SharedorPrivate_Shared)            0.696517
# 25                              (BuildingType_Apartment)            0.343284
# 26                              (BuildingType_Apartment)            0.139303
# 27                              (BuildingType_Apartment)            0.328358
# 28                              (BuildingType_Apartment)            0.776119
# 29                                           (Internet )            0.696517
# ...                                                  ...                 ...
# 27527   (SharedorPrivate_Shared, Hydro, AirConditioning)            0.154229
# 27528   (Laundry, Furnished_Yes, BuildingType_Apartment)            0.134328
# 27529  (Laundry, AirConditioning, BuildingType_Apartm...            0.134328
# 27530  (AirConditioning, Furnished_Yes, BuildingType_...            0.144279
# 27531           (Laundry, Hydro, BuildingType_Apartment)            0.134328
# 27532     (Hydro, Furnished_Yes, BuildingType_Apartment)            0.144279
# 27533   (AirConditioning, Hydro, BuildingType_Apartment)            0.144279
# 27534  (SharedorPrivate_Shared, Laundry, BuildingType...            0.154229
# 27535                (Internet , Furnished_Yes, Laundry)            0.134328
# 27536              (Internet , AirConditioning, Laundry)            0.144279
# 27537        (Internet , AirConditioning, Furnished_Yes)            0.149254
# 27538                        (Internet , Hydro, Laundry)            0.134328
# 27539                  (Internet , Hydro, Furnished_Yes)            0.144279
# 27540                (Internet , Hydro, AirConditioning)            0.149254
# 27541       (SharedorPrivate_Shared, Internet , Laundry)            0.154229
# 27542       (Internet , Laundry, BuildingType_Apartment)            0.139303
# 27543  (Internet , Furnished_Yes, BuildingType_Apartm...            0.149254
# 27544  (Internet , AirConditioning, BuildingType_Apar...            0.154229
# 27545         (Internet , Hydro, BuildingType_Apartment)            0.149254
# 27546   (Laundry, Hydro, Furnished_Yes, AirConditioning)            0.139303
# 27547  (Laundry, AirConditioning, Furnished_Yes, Buil...            0.144279
# 27548  (Laundry, Hydro, Furnished_Yes, BuildingType_A...            0.144279
# 27549  (Laundry, AirConditioning, Hydro, BuildingType...            0.144279
# 27550  (AirConditioning, Hydro, Furnished_Yes, Buildi...            0.154229
# 27551  (Internet , AirConditioning, Furnished_Yes, La...            0.154229
# 27552         (Internet , Hydro, Furnished_Yes, Laundry)            0.144279
# 27553       (Laundry, Internet , Hydro, AirConditioning)            0.154229
# 27554  (Internet , Laundry, Furnished_Yes, BuildingTy...            0.149254
# 27555  (Laundry, Internet , Hydro, BuildingType_Apart...            0.149254
# 27556  (BuildingType_Apartment, Hydro, AirConditionin...            0.154229
#
#        consequent support   support  confidence      lift  leverage  \
# 0                0.671642  0.368159    0.718447  1.069687  0.023985
# 1                0.815920  0.412935    0.805825  0.987627 -0.005173
# 2                0.726368  0.368159    0.718447  0.989094 -0.004059
# 3                0.776119  0.388060    0.757282  0.975728 -0.009653
# 4                0.910448  0.447761    0.873786  0.959733 -0.018787
# 5                0.815920  0.412935    0.805825  0.987627 -0.005173
# 6                0.905473  0.452736    0.883495  0.975728 -0.011262
# 7                0.696517  0.223881    0.789474  1.133459  0.026361
# 8                0.815920  0.233831    0.824561  1.010591  0.002450
# 9                0.726368  0.228856    0.807018  1.111031  0.022871
# 10               0.776119  0.233831    0.824561  1.062416  0.013737
# 11               0.910448  0.278607    0.982456  1.079091  0.020420
# 12               0.815920  0.243781    0.859649  1.053594  0.012401
# 13               0.905473  0.273632    0.964912  1.065645  0.016856
# 14               0.815920  0.169154    0.829268  1.016359  0.002723
# 15               0.776119  0.154229    0.756098  0.974203 -0.004084
# 16               0.910448  0.184080    0.902439  0.991204 -0.001634
# 17               0.815920  0.159204    0.780488  0.956573 -0.007228
# 18               0.905473  0.179104    0.878049  0.969713 -0.005594
# 19               0.696517  0.507463    0.755556  1.084762  0.039652
# 20               0.671642  0.507463    0.728571  1.084762  0.039652
# 21               0.696517  0.572139    0.701220  1.006751  0.003837
# 22               0.815920  0.572139    0.821429  1.006751  0.003837
# 23               0.696517  0.537313    0.739726  1.062035  0.031385
# 24               0.726368  0.537313    0.771429  1.062035  0.031385
# 25               0.696517  0.303483    0.884058  1.269255  0.064380
# 26               0.696517  0.109453    0.785714  1.128061  0.012425
# 27               0.696517  0.248756    0.757576  1.087662  0.020049
